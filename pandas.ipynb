# %% [markdown]
# <a href="https://colab.research.google.com/github/miguelmestre/pandas/blob/feat%2Fupdate-notebook/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas
# !pip install matplotlib

# %%
# Render our plots inline
# %matplotlib inline


import pandas as pd
import matplotlib.pyplot as plt

# Make the graphs a bit prettier, and bigger
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (15, 5)

# %%
url = "https://raw.githubusercontent.com/miguelmestre/pandas/main/data/bikes.csv"

# %%
broken_df = pd.read_csv(url)

# %%
broken_df.head()
# Out:
#   Date;Berri 1;Br�beuf (donn�es non disponibles);C�te-Sainte-Catherine;Maisonneuve 1;Maisonneuve 2;du Parc;Pierre-Dupuy;Rachel1;St-Urbain (donn�es non disponibles)
# 0                   01/01/2012;35;;0;38;51;26;10;16;
# 1                   02/01/2012;83;;1;68;153;53;6;43;
# 2                 03/01/2012;135;;2;104;248;89;3;58;
# 3                04/01/2012;144;;1;116;318;111;8;61;
# 4                05/01/2012;197;;2;124;330;97;13;95;

# %%
fixed_df = pd.read_csv(url, sep=';', encoding='latin1', parse_dates=['Date'], dayfirst=True, index_col='Date')

# %%
fixed_df.head()
# Out:
#             Berri 1  ...  St-Urbain (donnï¿½es non disponibles)
# Date                 ...
# 2012-01-01       35  ...                                    NaN
# 2012-01-02       83  ...                                    NaN
# 2012-01-03      135  ...                                    NaN
# 2012-01-04      144  ...                                    NaN
# 2012-01-05      197  ...                                    NaN
#
# [5 rows x 9 columns]

# %%
fixed_df['Berri 1']
# Out:
# Date
# 2012-01-01      35
# 2012-01-02      83
# 2012-01-03     135
# 2012-01-04     144
# 2012-01-05     197
#               ...
# 2012-11-01    2405
# 2012-11-02    1582
# 2012-11-03     844
# 2012-11-04     966
# 2012-11-05    2247
# Name: Berri 1, Length: 310, dtype: int64

# %%
fixed_df['Berri 1'].plot()

# %%
fixed_df.plot(figsize=(15, 10))
